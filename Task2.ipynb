# %% [markdown]
# # Основы языка Python для аналитиков (семинары)
# ##  Урок 2. Анализ датасета с помощью Pandas

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Upload widget is only available when the cell has been executed in the current browser session. Please rerun this cell to enable.

# %% [markdown]
# > Задание 1:
# >> Считать данные с помощью pandas:

# %%
df=pd.read_csv(open('kc_house_data.csv'))

# %% [markdown]
# >> Вывести на экран первые 5 строк:

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# >> Посмотреть на описание признаков и на их содержание:

# %%
df.sample()
# Out:
#              id             date     price  bedrooms  bathrooms  sqft_living  \
# 612  3905040800  20140925T000000  533600.0         3        2.5         1930
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 612      5080     2.0           0     0  ...      8        1930
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 612              0      1990             0    98029  47.5694 -122.001
#
#      sqft_living15  sqft_lot15
# 612           2190        5085
#
# [1 rows x 21 columns]

# %%
df.sample(frac=1)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 16605  5561400470  20150407T000000   585000.0         4       3.25
# 16093  3579700080  20140905T000000   383000.0         4       1.75
# 4088   7230000265  20140617T000000   499500.0         3       2.50
# 10551  6841700070  20150317T000000   510000.0         2       1.00
# 9880   8819900055  20150330T000000   503000.0         2       1.00
# ...           ...              ...        ...       ...        ...
# 18882  4218400455  20140708T000000  2180000.0         6       2.75
# 20359  7299600920  20141209T000000   279000.0         4       2.50
# 18543  2869200110  20140621T000000   930000.0         3       2.50
# 8866   8945300090  20140811T000000   205950.0         3       1.00
# 7398   4054710190  20140701T000000   695000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16605         3410     34939     2.0           0     0  ...      9
# 16093         1830     11090     1.0           0     0  ...      7
# 4088          2970     21907     2.0           0     0  ...      9
# 10551         1270      4500     1.5           0     0  ...      7
# 9880           870      4280     1.0           0     2  ...      6
# ...            ...       ...     ...         ...   ...  ...    ...
# 18882         4710     11000     2.0           0     3  ...     10
# 20359         2009      4800     2.0           0     0  ...      8
# 18543         3290      6830     2.0           0     0  ...     10
# 8866          1490      8239     1.0           0     0  ...      6
# 7398          2620     51354     2.0           0     0  ...      9
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 16605        2470            940      1992             0    98027  47.4590
# 16093        1060            770      1962             0    98028  47.7333
# 4088         2970              0      1998          2006    98059  47.4741
# 10551        1270              0      1919             0    98122  47.6059
# 9880          870              0      1921             0    98105  47.6697
# ...           ...            ...       ...           ...      ...      ...
# 18882        3690           1020      1931             0    98105  47.6622
# 20359        2009              0      2012             0    98092  47.2586
# 18543        3290              0      2000             0    98052  47.6702
# 8866         1490              0      1963             0    98023  47.3060
# 7398         2620              0      1998             0    98077  47.7211
#
#           long  sqft_living15  sqft_lot15
# 16605 -122.003           2450       39045
# 16093 -122.246           1990       10917
# 4088  -122.099           2040       27917
# 10551 -122.295           2140        4550
# 9880  -122.290           1750        4280
# ...        ...            ...         ...
# 18882 -122.272           2950        5300
# 20359 -122.200           1798        4800
# 18543 -122.142           3200        6227
# 8866  -122.370           1200        8470
# 7398  -122.028           2620       37042
#
# [21613 rows x 21 columns]

# %%
df.sample(frac=0.5)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 14764  1952000150  20140506T000000   530000.0         5       2.50
# 13020  1118001201  20150130T000000  2300000.0         4       2.50
# 1079    390100060  20150421T000000   325000.0         3       1.00
# 12098  7972604355  20140521T000000   218000.0         3       1.00
# 20115  7702080110  20141016T000000   535000.0         5       2.75
# ...           ...              ...        ...       ...        ...
# 67     3717000160  20141009T000000   287000.0         4       2.50
# 21083  1442880380  20140730T000000   439990.0         3       2.50
# 17361  7525211410  20140715T000000   425500.0         3       2.50
# 4266   8887001140  20140723T000000   562000.0         3       3.00
# 5096   7804700020  20140812T000000   961500.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14764         2910      9636     1.0           0     0  ...      7
# 13020         3370      8402     1.0           0     0  ...     10
# 1079          1040      7541     1.0           0     0  ...      6
# 12098         1020      7874     1.0           0     0  ...      7
# 20115         2620      6389     2.0           0     0  ...      9
# ...            ...       ...     ...         ...   ...  ...    ...
# 67            2240      4648     2.0           0     0  ...      7
# 21083         2340      5171     2.0           0     0  ...      8
# 17361         1970      2752     2.0           0     0  ...      8
# 4266          3290     80471     2.0           0     2  ...      8
# 5096          3910     14000     2.0           0     0  ...     10
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 14764        1690           1220      1964             0    98008  47.5803
# 13020        2240           1130      1962             0    98112  47.6349
# 1079         1040              0      1951             0    98133  47.7565
# 12098        1020              0      1956             0    98106  47.5175
# 20115        2620              0      2007             0    98028  47.7700
# ...           ...            ...       ...           ...      ...      ...
# 67           2240              0      2005             0    98001  47.3378
# 21083        2340              0      2013             0    98045  47.4832
# 17361        1970              0      1978             0    98052  47.6345
# 4266         2330            960      1975             0    98070  47.5040
# 5096         3910              0      1999             0    98008  47.6374
#
#           long  sqft_living15  sqft_lot15
# 14764 -122.119           2830       10385
# 13020 -122.290           3190        8700
# 1079  -122.339           1140        6100
# 12098 -122.346           1290        7320
# 20115 -122.236           2620        4504
# ...        ...            ...         ...
# 67    -122.257           2221        4557
# 21083 -121.772           2790        5684
# 17361 -122.108           1850        2778
# 4266  -122.464           1830       30494
# 5096  -122.120           2280       14000
#
# [10806 rows x 21 columns]

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# # Задание 2:
# > Проведите первичный анализ данных:
# >> Изучите типы данных:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# Найдите количество пропущенных ячеек в данных:

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Посчитайте основные статистики по всем признакам и поизучайте их:

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df.describe(include=['object'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# # Задание 3:
# > 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
print(df['price'].min(), '-', df['price'].max())
# Out:
# 75000.0 - 7700000.0

# %% [markdown]
# # 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
print((df['sqft_living'].mean() / df['sqft_lot'].mean()) *100, '%')
# Out:
# 13.76781757959227 %

# %% [markdown]
# # 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
df['floors'].nunique()
# Out:
# 6

# %% [markdown]
# > 3.4 Насколько хорошие состояния у домов в данных?

# %%
print(df['condition'].min())
print(df['condition'].max())
print(df['condition'].mean())
# Out:
# 1
# 5
# 3.4094295100171195

# %%
df['condition'].value_counts().sort_index()
# Out:
# 1       30
# 2      172
# 3    14031
# 4     5679
# 5     1701
# Name: condition, dtype: int64

# %% [markdown]
# > 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
print(df['yr_built'].min())
print(df['yr_built'].max())
# Out:
# 1900
# 2015

# %% [markdown]
# # Задание 4:
# > 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df[df['bedrooms']== 2 ]['price'].mean()
# Out:
# 401372.681884058

# %% [markdown]
# > 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df['price'] > 600000 ]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %% [markdown]
# > 4.3 Как много домов коснулся ремонт?

# %%
df[~(df['yr_renovated'] == 0)]['yr_renovated'].count()
# Out:
# 914

# %% [markdown]
# > 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
print((df[(df['grade'] > 10)]['price'].mean() - df[(df['grade'] < 4)]['price'].mean()))
# Out:
# 1488885.1175298805

# %% [markdown]
# # Задание 5:
# > 5.1 Выберите дом клиенту
# >> Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df[ (df["bathrooms"] > 2) &
    (df["waterfront"] == 1) &
    (df["sqft_basement"] > 0)
]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 656    3760500116  20141120T000000  3070000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 18914  9253900408  20150408T000000  1400000.0         3       2.75
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# 246           3650      8354     1.0           1     4  ...      9
# 300           4550     18641     1.0           1     4  ...     10
# 457           1970     20978     2.0           1     3  ...      9
# 656           3930     55867     1.0           1     4  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 18914         3130     19530     1.0           1     4  ...      8
# 20325         4410     10756     2.0           1     4  ...     11
# 20767         4360      8175     2.5           1     4  ...     10
# 21201         3760      5634     2.0           1     4  ...     11
# 21576         4850     10584     2.0           1     4  ...     10
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 49           2165            588      1953             0    98070  47.4041
# 246          1830           1820      2000             0    98074  47.6338
# 300          2600           1950      2002             0    98074  47.6053
# 457          1770            200      1980             0    98070  47.3844
# 656          2330           1600      1957             0    98034  47.7022
# ...           ...            ...       ...           ...      ...      ...
# 18914        1690           1440      1947          1984    98008  47.5895
# 20325        3430            980      2014             0    98056  47.5283
# 20767        3940            420      2007             0    98008  47.5724
# 21201        2830            930      2014             0    98056  47.5285
# 21576        3540           1310      2007             0    98008  47.5943
#
#           long  sqft_living15  sqft_lot15
# 49    -122.451           2680       72513
# 246   -122.072           3120       18841
# 300   -122.077           4550       19508
# 457   -122.438           2280       75396
# 656   -122.224           2730       26324
# ...        ...            ...         ...
# 18914 -122.111           2980       18782
# 20325 -122.205           3550        5634
# 20767 -122.104           2670        8525
# 21201 -122.205           3560        5762
# 21576 -122.110           3470       18270
#
# [76 rows x 21 columns]

# %% [markdown]
# > 5.2 Выберите дом клиенту
# >> Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
cost_max = df[
    ((df["waterfront"] == 1) | (df["view"] == 4)) &
    (df["condition"] > 4.5) &
    (df["yr_built"] > 1978)
]['price'].max()

cost_min = df[
    ((df["waterfront"] == 1) | (df["view"] == 4)) &
    (df["condition"] > 4.5) &
    (df["yr_built"] > 1978)
]['price'].min()

print(cost_min, '-', cost_max)
# Out:
# 1295000.0 - 3000000.0

# %% [markdown]
# > 5.3 Выберите дом клиенту
# >> Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df[
    (df["sqft_basement"] == 0) &
    (df["floors"] ==2) &
    (df["price"] < 150000)
]['condition'].mean()
# Out:
# 2.8333333333333335
